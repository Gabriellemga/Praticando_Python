# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriellemga/Praticando_Python/blob/main/Praticando_Python__Normalizando_arquivos_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio 1 - Coletando os dados

# %% [markdown]
# João possui um arquivo JSON contendo dados sobre as vendas da loja onde trabalha, salvo em sua máquina. Ele deseja processar esse arquivo no Python utilizando a biblioteca Pandas.
#
# Ajude João a criar um código que carregue o arquivo JSON como um DataFrame.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_json('/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_1.json')
df
# Out:
#    id_pedido  id_cliente     nome_cliente  id_produto     nome_produto  \
# 0          1         101      Alice Silva         201  Camiseta Básica
# 1          2         102      Bruno Souza         202  Tênis Esportivo
# 2          3         103    Carla Pereira         203  Relógio Digital
# 3          4         104  Daniel Oliveira         204      Calça Jeans
# 4         15         115     Olivia Rocha         215     Tênis Casual
#
#     categoria  quantidade  preco_unitario  preco_total data_pedido     status
# 0      Roupas           2              50          100  2025-01-01   Entregue
# 1    Calçados           1             200          200  2025-01-02   Pendente
# 2  Acessórios           1             150          150  2025-01-03   Entregue
# 3      Roupas           2             120          240  2025-01-04  Cancelado
# 4    Calçados           1             220          220  2025-01-15   Entregue

# %% [markdown]
# # Desafio 2- Definindo a melhor forma de coletar dados

# %% [markdown]
# Márcia recebeu dois conjuntos de dados em formato JSON. O primeiro conjunto contém informações referentes à primeira semana do mês na loja onde trabalha, e o segundo conjunto refere-se à segunda semana.
#
# Márcia deseja saber a forma mais eficiente de carregar esses dados no Python para manipulá-los como DataFrames. Analise os conjuntos e indique a melhor abordagem para resolver o problema.

# %%
dados1 = pd.read_json('/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_2_1.json')
dados1
# Out:
#    id_pedido  id_cliente   nome_cliente  id_produto   nome_produto  \
# 0         10         110    João Vieira         210     Smartphone
# 1         11         111  Karen Martins         211    Mouse Gamer
# 2         12         112   Lucas Mendes         212      Bicicleta
# 3         13         113  Mariana Lopes         213  Óculos de Sol
# 4         14         114   Natan Santos         214         Tablet
#
#                                categorias  quantidade  preco_unitario  \
# 0  [Eletrônicos, Comunicação, Tecnologia]           1            2500
# 1        [Eletrônicos, Acessórios, Games]           1             150
# 2           [Esportes, Lazer, Transporte]           1            1200
# 3            [Acessórios, Moda, Proteção]           1             300
# 4     [Eletrônicos, Tecnologia, Educação]           1            1500
#
#    preco_total data_pedido     status
# 0         2500  2025-01-10   Pendente
# 1          150  2025-01-11   Entregue
# ...

# %%
dados2 = pd.read_json('/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_2_2.json')
dados2
# Out:
#    id_pedido  id_cliente    nome_cliente  id_produto           nome_produto  \
# 0          5         105   Eduarda Costa         205        Mochila Escolar
# 1          6         106   Fernando Lima         206               Notebook
# 2          7         107  Gabriela Souza         207         Fone de Ouvido
# 3          8         108    Hugo Almeida         208       Jaqueta de Couro
# 4          9         109   Isabela Nunes         209  Caderno Universitário
#
#      categoria  quantidade  preco_unitario  preco_total data_pedido    status  \
# 0   Acessórios           1             180          180  2025-01-05  Entregue
# 1  Eletrônicos           1            3000         3000  2025-01-06  Pendente
# 2  Eletrônicos           1             250          250  2025-01-07  Entregue
# 3       Roupas           1             350          350  2025-01-08  Entregue
# 4    Papelaria           5              20          100  2025-01-09  Entregue
#
# ...

# %% [markdown]
# # Desafio 3 - Identificando níveis de dicionários

# %% [markdown]
# Thais utilizou a função pd.read_json para carregar um arquivo JSON recebido em sua empresa. No entanto, ela notou que não conseguia acessar corretamente todos os dados do arquivo no DataFrame.
#
# Um problema identificado foi que a coluna detalhes_compra apresentava informações importantes em formato de dicionário, dificultando a manipulação dos dados:
#
# Ajude Thais a acessar todas as colunas e informações disponíveis nos dados

# %%
import json
import pandas as pd

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_3.json'

# %%
with open(url, 'r') as arquivo:
    dados = json.load(arquivo)
dados
# Out:
# [{'id_pedido': 16,
#   'id_cliente': 116,
#   'nome_cliente': 'Paulo Barros',
#   'data_pedido': '2025-01-16',
#   'status': 'Pendente',
#   'detalhes_compra': {'id_produto': 216,
#    'nome_produto': 'Câmera Digital',
#    'categoria': 'Eletrônicos',
#    'quantidade': 1,
#    'preco_unitario': 2000.0,
#    'preco_total': 2000.0}},
#  {'id_pedido': 17,
#   'id_cliente': 117,
#   'nome_cliente': 'Quezia Fernandes',
#   'data_pedido': '2025-01-17',
#   'status': 'Entregue',
#   'detalhes_compra': {'id_produto': 217,
#    'nome_produto': 'Bolsa de Couro',
#    'categoria': 'Acessórios',
#    'quantidade': 1,
#    'preco_unitario': 400.0,
#    'preco_total': 400.0}},
#  {'id_pedido': 18,
#   'id_cliente': 118,
#   'nome_cliente': 'Rafael Cardoso',
#   'data_pedido': '2025-01-18',
#   'status': 'Cancelado',
#   'detalhes_compra': {'id_produto': 218,
#    'nome_produto': 'Livro de Ficção',
#    'categoria': 'Livros',
#    'quantidade': 2,
#    'preco_unitario': 35.0,
# ...

# %%
dados = pd.json_normalize(dados, sep = '_')
dados
# Out:
#    id_pedido  id_cliente      nome_cliente data_pedido     status  \
# 0         16         116      Paulo Barros  2025-01-16   Pendente
# 1         17         117  Quezia Fernandes  2025-01-17   Entregue
# 2         18         118    Rafael Cardoso  2025-01-18  Cancelado
# 3         19         119     Sofia Ribeiro  2025-01-19   Entregue
# 4         20         120      Tiago Moraes  2025-01-20   Entregue
#
#    detalhes_compra_id_produto detalhes_compra_nome_produto  \
# 0                         216               Câmera Digital
# 1                         217               Bolsa de Couro
# 2                         218              Livro de Ficção
# 3                         219                      Perfume
# 4                         220                 Guarda-Chuva
#
#   detalhes_compra_categoria  detalhes_compra_quantidade  \
# 0               Eletrônicos                           1
# 1                Acessórios                           1
# ...

# %%
colunas = [col.replace('detalhes_','') for col in dados.columns]

# %%
dados.columns = colunas
dados
# Out:
#    id_pedido  id_cliente      nome_cliente data_pedido     status  \
# 0         16         116      Paulo Barros  2025-01-16   Pendente
# 1         17         117  Quezia Fernandes  2025-01-17   Entregue
# 2         18         118    Rafael Cardoso  2025-01-18  Cancelado
# 3         19         119     Sofia Ribeiro  2025-01-19   Entregue
# 4         20         120      Tiago Moraes  2025-01-20   Entregue
#
#    _compra_id_produto _compra_nome_produto _compra_categoria  \
# 0                 216       Câmera Digital       Eletrônicos
# 1                 217       Bolsa de Couro        Acessórios
# 2                 218      Livro de Ficção            Livros
# 3                 219              Perfume            Beleza
# 4                 220         Guarda-Chuva        Acessórios
#
#    _compra_quantidade  _compra_preco_unitario  _compra_preco_total
# 0                   1                  2000.0               2000.0
# ...

# %% [markdown]
# # Desafio 4 - Lidando com aninhamento de 3 níveis

# %% [markdown]
# Fábio recebeu um conjunto de dados relacionados às vendas da empresa onde trabalha. Ao inspecionar o arquivo, percebeu que se tratava de um JSON com uma estrutura aninhada de 3 níveis.
#
# Como Fábio nunca trabalhou com a normalização de arquivos JSON, ele não sabe como lidar com um arquivo aninhado dessa complexidade. O que Fábio pode fazer para transformar esse JSON em um conjunto de dados utilizável?

# %%
import pandas as pd
import json

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_4.json'

# %%
with open(url, 'r') as arquivo:
    dados4 = json.load(arquivo)

# %%
df4 = pd.json_normalize(dados4)
df4
# Out:
#    id_pedido data_pedido     status  cliente.id_cliente cliente.nome_cliente  \
# 0         21  2025-01-21   Entregue                 121        Ursula Castro
# 1         22  2025-01-22   Pendente                 122       Victor Andrade
# 2         23  2025-01-23   Entregue                 123         Wagner Neves
# 3         24  2025-01-24   Entregue                 124       Xavier Almeida
# 4         25  2025-01-25  Cancelado                 125          Yasmin Dias
#
#    detalhes_compra.produto.id_produto detalhes_compra.produto.nome_produto  \
# 0                                 221                    Sandália Feminina
# 1                                 222                             Chuteira
# 2                                 223                  Carregador Portátil
# 3                                 224                      Bola de Futebol
# 4                                 225                   Maquiagem Completa
#
# ...

# %% [markdown]
# # Desafio 5 - Especificando o separador

# %% [markdown]
# Tiago utilizou a normalização para transformar um arquivo JSON aninhado em um DataFrame no ambiente Python. Contudo, ele percebeu que o separador padrão ('.') nos nomes das colunas criadas a partir dos dados aninhados não atende às suas necessidades.
#
# Tiago gostaria de usar o caractere '_' como separador, resultando em nomes de colunas como cliente_id_cliente, cliente_nome_cliente, compra_id_produto e compra_nome_produto. Como Tiago pode alterar o separador de colunas para '_' ao realizar a normalização?

# %%
import pandas as pd
import json

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_5.json'

# %%
with open(url, 'r') as arquivo:
    dados5 = json.load(arquivo)

# %%
df5 = pd.json_normalize(dados5, sep = '_')
df5
# Out:
#    id_pedido data_pedido     status  cliente_id_cliente cliente_nome_cliente  \
# 0         26  2025-01-26   Entregue                 126           Zeca Costa
# 1         27  2025-01-27   Pendente                 127          Amanda Melo
# 2         28  2025-01-28   Entregue                 128         Bruna Santos
# 3         29  2025-01-29  Cancelado                 129         Carlos Silva
# 4         30  2025-01-30   Entregue                 130          Débora Lima
#
#    compra_id_produto    compra_nome_produto  compra_categoria  \
# 0                226  Cadeira de Escritório            Móveis
# 1                227         Colar de Prata        Acessórios
# 2                228          Fogão 4 Bocas  Eletrodomésticos
# 3                229              Geladeira  Eletrodomésticos
# 4                230       Teclado Mecânico       Eletrônicos
#
#    compra_quantidade  compra_preco_unitario  compra_preco_total
# 0                  1                  550.0               550.0
# ...

# %% [markdown]
# # Desafio 6 - Tirando dicionário de listas

# %% [markdown]
# Cristina recebeu um arquivo JSON com dados importantes para sua avaliação de lojas. Contudo, ao aplicar a função json_normalize, o resultado obtido não foi um DataFrame normalizado e organizado como esperado:
#
# Ajude Cristina a criar um DataFrame que permita a manipulação adequada de todos os dados.

# %%
import pandas as pd
import json

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_6.json'

# %%
with open(url, 'r') as arquivo:
    dados6 = json.load(arquivo)

# %%
df6 = pd.json_normalize(dados6, record_path = 'lista_lojas')
df6
# Out:
#    id_loja     nome_loja        cidade estado    categoria  vendas_mensais  \
# 0        5  Loja Épsilon      Salvador     BA       Livros             300
# 1        6     Loja Zeta     Fortaleza     CE  Eletrônicos             100
# 2        7      Loja Eta  Porto Alegre     RS       Roupas             250
# 3        8    Loja Theta        Manaus     AM     Calçados              70
#
#    faturamento_mensal
# 0             75000.0
# 1             50000.0
# 2             87500.0
# 3             21000.0

# %% [markdown]
# # Desafio 7 - Normalizando várias listas

# %% [markdown]
# Juan recebeu um conjunto de dados em formato JSON e precisa normalizá-lo para acessar as informações de maneira estruturada. No entanto, ao utilizar json_normalize, ele identificou que o arquivo continha duas listas:
#
# Como Juan pode estruturar esses dados em um único DataFrame?

# %%
import pandas as pd
import json

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_7.json'

# %%
with open (url, 'r') as arquivo:
  dados7 = json.load(arquivo)

# %%
dfsudeste = pd.json_normalize(dados7, record_path ='lojas_sudeste')
dfsudeste
# Out:
#    id_loja   nome_loja          cidade estado    categoria  vendas_mensais  \
# 0        1  Loja Alpha       São Paulo     SP  Eletrônicos             150
# 1        2   Loja Beta  Rio de Janeiro     RJ       Roupas             200
#
#    faturamento_mensal
# 0             45000.0
# 1             60000.0

# %%
dfsul = pd.json_normalize(dados7, record_path ='lojas_sul')
dfsul
# Out:
#    id_loja   nome_loja          cidade estado   categoria  vendas_mensais  \
# 0        3  Loja Gamma  Belo Horizonte     MG    Calçados             120
# 1        4  Loja Delta        Curitiba     PR  Acessórios              80
#
#    faturamento_mensal
# 0             36000.0
# 1             24000.0

# %%
df = pd.concat([dfsudeste, dfsul], ignore_index=True)
df
# Out:
#    id_loja   nome_loja          cidade estado    categoria  vendas_mensais  \
# 0        1  Loja Alpha       São Paulo     SP  Eletrônicos             150
# 1        2   Loja Beta  Rio de Janeiro     RJ       Roupas             200
# 2        3  Loja Gamma  Belo Horizonte     MG     Calçados             120
# 3        4  Loja Delta        Curitiba     PR   Acessórios              80
#
#    faturamento_mensal
# 0             45000.0
# 1             60000.0
# 2             36000.0
# 3             24000.0

# %% [markdown]
# # Desafio 8 - Lidando com subníveis de listas

# %% [markdown]
# Paula está trabalhando com um conjunto de dados que contém duas listas aninhadas dentro de uma chave chamada lojas. Devido a essa estrutura, ela está enfrentando dificuldades para transformar o documento em um DataFrame manipulável.
#
# Ajude Paula a estruturar os dados em um DataFrame adequado para análise.

# %%
import pandas as pd
import json

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_8.json'

# %%
with open (url, 'r') as arquivo:
  dados8 = json.load(arquivo)

# %%
df8 = pd.json_normalize(dados8)
df8
# Out:
#                                 lojas.lojas_nordeste  \
# 0  [{'id_loja': 9, 'nome_loja': 'Loja Iota', 'cid...
#
#                                    lojas.lojas_norte
# 0  [{'id_loja': 11, 'nome_loja': 'Loja Lambda', '...

# %%
dfnorte = pd.json_normalize(df8['lojas.lojas_norte'][0])
dfnorte
# Out:
#    id_loja    nome_loja  cidade estado    categoria  vendas_mensais  \
# 0       11  Loja Lambda  Manaus     AM  Eletrônicos             220
# 1       12      Loja Mu   Belém     PA       Roupas             160
#
#    faturamento_mensal
# 0            110000.0
# 1             48000.0

# %%
dfnordeste = pd.json_normalize(df8['lojas.lojas_nordeste'][0])
dfnordeste
# Out:
#    id_loja   nome_loja     cidade estado   categoria  vendas_mensais  \
# 0        9   Loja Iota     Recife     PE  Acessórios              95
# 1       10  Loja Kappa  Fortaleza     CE      Livros             180
#
#    faturamento_mensal
# 0             28500.0
# 1             54000.0

# %%
df = pd.concat([dfnordeste, dfnorte], ignore_index=True)
df
# Out:
#    id_loja    nome_loja     cidade estado    categoria  vendas_mensais  \
# 0        9    Loja Iota     Recife     PE   Acessórios              95
# 1       10   Loja Kappa  Fortaleza     CE       Livros             180
# 2       11  Loja Lambda     Manaus     AM  Eletrônicos             220
# 3       12      Loja Mu      Belém     PA       Roupas             160
#
#    faturamento_mensal
# 0             28500.0
# 1             54000.0
# 2            110000.0
# 3             48000.0

# %% [markdown]
# # Desafio 9 - Encontrando colunas perdidas

# %% [markdown]
# Após aplicar a normalização em uma lista presente no banco de dados, Diego percebeu que algumas colunas estavam ausentes no DataFrame resultante, embora estivessem nos dados originais. Ele sabe que o conjunto de dados deveria conter as seguintes colunas:
#
# ['cidade', 'estado', 'categoria', 'vendas_mensais', 'faturamento_mensal', 'id_loja', 'nome_loja']
#
# No entanto, após aplicar a função json_normalize, as colunas 'id_loja' e 'nome_loja' não foram incluídas no DataFrame.
#
# O que Diego pode ter esquecido de fazer ao configurar o código de normalização? Qual seria a forma ideal de resolver esse problema?

# %%
import pandas as pd
import json

# %%
url = '/content/drive/MyDrive/Dados/Dados_normalizando_json/questao_9.json'

# %%
df9 = pd.read_json(url)
df9
# Out:
#    id_loja     nome_loja                                             vendas
# 0       13       Loja Nu  [{'cidade': 'Natal', 'estado': 'RN', 'categori...
# 1       14       Loja Xi  [{'cidade': 'Goiânia', 'estado': 'GO', 'catego...
# 2       15  Loja Omicron  [{'cidade': 'São Luís', 'estado': 'MA', 'categ...
# 3       16       Loja Pi  [{'cidade': 'Maceió', 'estado': 'AL', 'categor...

# %%
with open(url, 'r') as arquivo:
  dados = json.load(arquivo)

# %%
df9 = pd.json_normalize(dados, meta =['id_loja', 'nome_loja'], record_path = 'vendas' )
df9
# Out:
#      cidade estado    categoria  vendas_mensais  faturamento_mensal id_loja  \
# 0     Natal     RN     Calçados             140             42000.0      13
# 1   Goiânia     GO   Acessórios              75             22500.0      14
# 2  São Luís     MA       Livros             210             63000.0      15
# 3    Maceió     AL  Eletrônicos              50             25000.0      16
#
#       nome_loja
# 0       Loja Nu
# 1       Loja Xi
# 2  Loja Omicron
# 3       Loja Pi

# %% [markdown]
# # Desafio 10 - Construindo o melhor DataFrame

# %% [markdown]
# Agora que você explorou diversas formas de trabalhar com dicionários utilizando a função json_normalize e aprendeu a identificar as características de arquivos JSON para aplicar a normalização adequada, crie um código que permita construir um DataFrame manipulável a partir dos dados estruturados abaixo:

# %%
dados = [
    {
        "id_loja": 17,
        "nome_loja": "Loja Rho",
        "detalhes": [
            {"cidade": "João Pessoa", "estado": "PB"}
        ],
        "vendas": [
            {"categoria": "Roupas", "vendas_mensais": 125, "faturamento_mensal": 37500.0}
        ]
    },
    {
        "id_loja": 18,
        "nome_loja": "Loja Sigma",
        "detalhes": [
            {"cidade": "Vitória", "estado": "ES"}
        ],
        "vendas": [
            {"categoria": "Calçados", "vendas_mensais": 180, "faturamento_mensal": 54000.0}
        ]
    },
    {
        "id_loja": 19,
        "nome_loja": "Loja Tau",
        "detalhes": [
            {"cidade": "Aracaju", "estado": "SE"}
        ],
        "vendas": [
            {"categoria": "Acessórios", "vendas_mensais": 90, "faturamento_mensal": 27000.0}
        ]
    },
    {
        "id_loja": 20,
        "nome_loja": "Loja Upsilon",
        "detalhes": [
            {"cidade": "Teresina", "estado": "PI"}
        ],
        "vendas": [
            {"categoria": "Livros", "vendas_mensais": 240, "faturamento_mensal": 72000.0}
        ]
    }
]

# %%
df_detalhes = pd.json_normalize(dados, record_path = 'detalhes', meta = ['id_loja', 'nome_loja'])
df_detalhes
# Out:
#         cidade estado id_loja     nome_loja
# 0  João Pessoa     PB      17      Loja Rho
# 1      Vitória     ES      18    Loja Sigma
# 2      Aracaju     SE      19      Loja Tau
# 3     Teresina     PI      20  Loja Upsilon

# %%
df_vendas = pd.json_normalize(dados, record_path = 'vendas', meta = ['id_loja', 'nome_loja'])
df_vendas
# Out:
#     categoria  vendas_mensais  faturamento_mensal id_loja     nome_loja
# 0      Roupas             125             37500.0      17      Loja Rho
# 1    Calçados             180             54000.0      18    Loja Sigma
# 2  Acessórios              90             27000.0      19      Loja Tau
# 3      Livros             240             72000.0      20  Loja Upsilon

# %%
df = df_detalhes.merge(df_vendas, how = 'left' , on = ['id_loja', 'nome_loja'])
df
# Out:
#         cidade estado id_loja     nome_loja   categoria  vendas_mensais  \
# 0  João Pessoa     PB      17      Loja Rho      Roupas             125
# 1      Vitória     ES      18    Loja Sigma    Calçados             180
# 2      Aracaju     SE      19      Loja Tau  Acessórios              90
# 3     Teresina     PI      20  Loja Upsilon      Livros             240
#
#    faturamento_mensal
# 0             37500.0
# 1             54000.0
# 2             27000.0
# 3             72000.0
